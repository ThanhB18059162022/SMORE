# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhB18059162022/SMORE/blob/dev/SMORE_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kennethorq/SMORE.git
# Out:
# Cloning into 'SMORE'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 99 (delta 42), reused 83 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (99/99), 1.99 MiB | 12.72 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# !cp "/content/drive/MyDrive/CTU/HK4/Chuyên đề phát triển các hệ thống thông tin thông minh (CTH004)/BM3.zip" "./BM3.zip"
# Out:
# cp: cannot stat '/content/drive/MyDrive/CTU/HK4/Chuyên đề phát triển các hệ thống thông tin thông minh (CTH004)/BM3.zip': No such file or directory

# %%
# !unzip "/content/SMORE/data/baby.zip" -d "/content/SMORE/data/baby"
# Out:
# Archive:  /content/SMORE/data/baby.zip
#    creating: /content/SMORE/data/baby/baby/
#   inflating: /content/SMORE/data/baby/baby/baby.inter
#   inflating: /content/SMORE/data/baby/baby/image_feat.npy
#   inflating: /content/SMORE/data/baby/baby/i_id_mapping.csv
#   inflating: /content/SMORE/data/baby/baby/text_feat.npy
#   inflating: /content/SMORE/data/baby/baby/user_graph_dict.npy
#   inflating: /content/SMORE/data/baby/baby/u_id_mapping.csv

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/smore.zip" smore.zip

# %%
# !unzip smore.zip
# Out:
# Archive:  smore.zip
#    creating: SMORE/
#    creating: SMORE/src/
#    creating: SMORE/src/log/
#   inflating: SMORE/src/log/SMORE-baby-Nov-27-2025-02-06-58.log
#   inflating: SMORE/src/log/SMORE-baby-Nov-27-2025-02-19-59.log
#   inflating: SMORE/src/log/SMORE-baby-Nov-27-2025-02-19-04.log
#    creating: SMORE/src/configs/
#   inflating: SMORE/src/configs/.DS_Store
#    creating: SMORE/src/configs/dataset/
#   inflating: SMORE/src/configs/dataset/elec.yaml
#   inflating: SMORE/src/configs/dataset/microlens.yaml
#   inflating: SMORE/src/configs/dataset/clothing.yaml
#   inflating: SMORE/src/configs/dataset/sports.yaml
#   inflating: SMORE/src/configs/dataset/baby.yaml
#    creating: SMORE/src/configs/model/
#   inflating: SMORE/src/configs/model/SMORE.yaml
#   inflating: SMORE/src/configs/model/.DS_Store
#   inflating: SMORE/src/configs/mg.yaml
#   inflating: SMORE/src/configs/overall.yaml
#   inflating: SMORE/src/.DS_Store
#    creating: SMORE/src/utils/
# ...

# %%
# %pip install lmdb

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
# %pip install torch-scatter # -f https://data.pyg.org/whl/torch-2.9.0+cu126.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.9.0+cu126.html
# ...
#   Using cached torch_scatter-2.1.2.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.2-cp312-cp312-linux_x86_64.whl size=3857027 sha256=95a66135f892cf8dd8d43655e698a211b6b8a66e1196d0d4018842193989af4d
#   Stored in directory: /root/.cache/pip/wheels/84/20/50/44800723f57cd798630e77b3ec83bc80bd26a1e3dc3a672ef5
# Successfully built torch-scatter
# ...

# %%
import os

os.chdir('SMORE/src')
# !python main.py -m SMORE -d baby
os.chdir('../../')
# Out:
# 27 Nov 02:55    INFO ██Server: 	0883f46acb30
# 27 Nov 02:55    INFO ██Dir: 	/content/SMORE/src
#
# 27 Nov 02:55    INFO
# gpu_id=0
# use_gpu=True
# seed=[999]
# data_path=../data/
# inter_splitting_label=x_label
# filter_out_cod_start_users=True
# is_multimodal_model=True
# checkpoint_dir=saved
# save_recommended_topk=True
# recommend_topk=recommend_topk/
# embedding_size=64
# weight_decay=0.0
# req_training=True
# epochs=1000
# stopping_step=20
# train_batch_size=2048
# learner=adam
# learning_rate=0.001
# learning_rate_scheduler=[0.96, 50]
# eval_step=1
# training_neg_sample_num=1
# use_neg_sampling=True
# use_full_sampling=False
# NEG_PREFIX=neg__
# USER_ID_FIELD=userID
# ITEM_ID_FIELD=itemID
# TIME_FIELD=timestamp
# field_separator=
# metrics=['Recall', 'NDCG', 'Precision', 'MAP']
# topk=[5, 10, 20, 50]
# valid_metric=Recall@20
# eval_batch_size=4096
# use_raw_features=False
# max_txt_len=32
# max_img_size=256
# vocab_size=30522
# type_vocab_size=2
# hidden_size=4
# ...

# %%
# !zip -r smore.zip SMORE
# Out:
# updating: SMORE/ (stored 0%)
# updating: SMORE/src/ (stored 0%)
# updating: SMORE/src/log/ (stored 0%)
# updating: SMORE/src/log/SMORE-baby-Nov-27-2025-02-06-58.log (deflated 46%)
# updating: SMORE/src/log/SMORE-baby-Nov-27-2025-02-19-59.log (deflated 58%)
# updating: SMORE/src/log/SMORE-baby-Nov-27-2025-02-19-04.log (deflated 46%)
# updating: SMORE/src/configs/ (stored 0%)
# updating: SMORE/src/configs/.DS_Store (deflated 93%)
# updating: SMORE/src/configs/dataset/ (stored 0%)
# updating: SMORE/src/configs/dataset/elec.yaml (deflated 39%)
# updating: SMORE/src/configs/dataset/microlens.yaml (deflated 39%)
# updating: SMORE/src/configs/dataset/clothing.yaml (deflated 39%)
# updating: SMORE/src/configs/dataset/sports.yaml (deflated 39%)
# updating: SMORE/src/configs/dataset/baby.yaml (deflated 39%)
# updating: SMORE/src/configs/model/ (stored 0%)
# updating: SMORE/src/configs/model/SMORE.yaml (deflated 41%)
# updating: SMORE/src/configs/model/.DS_Store (deflated 97%)
# ...

# %%
# !mv smore.zip /"content/drive/MyDrive/Colab Notebooks"
